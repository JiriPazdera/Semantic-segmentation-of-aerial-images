# %%
# Images and masks will be stored in a dataset in RGB format 
# Images end with .jpg while masks end with .png
# cv2 is used to read images and masks, so they are loaded in BGR
# Right after they are loaded, we convert them to RGB for consistency
# In very step of this code where any image is RGB format, it is indeed RGB not BGR
# The first option is that images are stored in 25cm per pixel resolution
# We work with data from CUZK, where all data are in 12,5cm per pixel resolution so resclase has to be part of preprocesing before this code
# First input will be 256x256x3 tensor later 512x512x3 will be tested
import numpy as np
np.object = object    
np.int = int    
np.float = float    
np.bool = bool 

import os

os.environ["SM_FRAMEWORK"] = "tf.keras"


import re
import random
import pickle

import cv2

import tensorflow
from PIL import Image
from matplotlib import pyplot as plt
from patchify import patchify
from enum import Enum
import segmentation_models as sm
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.utils import to_categorical

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from simple_multi_unet_model import *
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
# os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

# %%
if tensorflow.test.gpu_device_name():
    print('GPU found')
else:
    print("No GPU found")

scaler = MinMaxScaler()

root_directory = "/home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE"

patch_size = 512 #mozna zmenim na 512
# Out:
# GPU found
# 2024-04-27 11:34:22.473407: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-27 11:34:22.488488: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:22.505342: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:22.505489: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:22.907139: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:22.907231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:22.907288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:22.907360: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 9666 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
image_dataset = []

# Sort the directories based on the last number in their names
def get_last_number(filename):
    return int(re.findall(r'\d+', filename)[-1])


for path, subdirs, files in sorted(os.walk(root_directory), key=lambda x: get_last_number(x[0])):
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'images':   # Find all 'masks' directories
        images = os.listdir(path)  # List of all mask names in this subdirectory
        for i, img_name in enumerate(sorted(images)):
            if img_name.endswith(".jpg"):   # Only read png images (masks in this dataset)
                image = cv2.imread(os.path.join(path, img_name), 1)  # Read each image as RGB
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                size_x = (image.shape[1] // patch_size) * patch_size  # Nearest size divisible by our patch size
                size_y = (image.shape[0] // patch_size) * patch_size  # Nearest size divisible by our patch size

                new_x = size_x - (size_x % patch_size)
                new_y = size_y - (size_y % patch_size)

                image = image[:new_x, :new_y, :]

                print("Now patchifying image:", os.path.join(path, img_name))
                img_patches = patchify(image, (patch_size, patch_size, 3), step=patch_size)  # Step=patch_size for non-overlapping patches

                for i in range(img_patches.shape[0]):
                    for j in range(img_patches.shape[1]):
                        single_patch_img = img_patches[i, j, 0, :,:,:]
                        image_dataset.append(single_patch_img)
# Out:
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 1/images/BOS12_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 1/images/BOS12_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 1/images/BOS12_8.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 1/images/BOS12_9.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/images/OLOM882_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/images/OLOM882_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/images/OLOM882_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/images/OLOM882_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/images/OLOM882_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/images/OLOM882_5.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/images/PROS36_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/images/PROS36_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/images/PROS36_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/images/PROS36_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/images/PROS36_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/images/PROS36_5.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/images/PROS36_6.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/images/PROS36_7.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/images/PROS36_8.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 5/images/PROS83_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 5/images/PROS83_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 5/images/PROS83_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 5/images/PROS83_5.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/images/PROS362_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/images/PROS362_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/images/PROS362_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/images/PROS362_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/images/PROS362_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/images/PROS362_5.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 7/images/VYSK14_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 7/images/VYSK14_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 7/images/VYSK14_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 7/images/VYSK14_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_10.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_11.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_12.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_13.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_5.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_6.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_7.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_8.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/images/VYSK111_9.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 9/images/VYSK112_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 9/images/VYSK112_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 9/images/VYSK112_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 9/images/VYSK112_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 9/images/VYSK112_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 10/images/VYSK121_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 10/images/VYSK121_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 10/images/VYSK121_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 10/images/VYSK121_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 11/images/VYSK122_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 11/images/VYSK122_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 11/images/VYSK122_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 11/images/VYSK122_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 12/images/VYSK151_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 12/images/VYSK151_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 12/images/VYSK151_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 12/images/VYSK151_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 12/images/VYSK151_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 13/images/VYSK152_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 13/images/VYSK152_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 14/images/BLAN981_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 14/images/BLAN981_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 14/images/BLAN981_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 14/images/BLAN981_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 15/images/BLAN982_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 15/images/BLAN982_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 15/images/BLAN982_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 15/images/BLAN982_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_11.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_13.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_15.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_16.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_17.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_19.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_7.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_8.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/images/KROM371_9.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_12.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_13.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_16.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_18.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_20.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_23.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_24.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_8.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/images/MKRU491_9.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/images/VYSK101_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/images/VYSK101_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/images/VYSK101_11.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/images/VYSK101_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/images/VYSK101_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/images/VYSK101_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/images/VYSK101_5.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/images/VYSK131_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/images/VYSK131_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/images/VYSK131_10.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/images/VYSK131_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/images/VYSK131_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/images/VYSK131_5.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/images/VYSK131_6.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/images/VYSK131_7.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/images/VYSK131_8.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_14.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_15.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_16.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_17.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_18.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_5.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_6.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_7.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_8.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/images/KROM341_9.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_10.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_11.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_12.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_13.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_14.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_15.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_5.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_6.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_7.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_8.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/images/VYSK301_9.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/images/VYSK302_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/images/VYSK302_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/images/VYSK302_10.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/images/VYSK302_11.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/images/VYSK302_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/images/VYSK302_5.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/images/VYSK302_8.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/images/VYSK303_0.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/images/VYSK303_1.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/images/VYSK303_2.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/images/VYSK303_3.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/images/VYSK303_4.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/images/VYSK303_5.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/images/VYSK303_6.jpg
# Now patchifying image: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/images/VYSK303_8.jpg

# %%
mask_dataset = []

# Sort the directories based on the last number in their names
def get_last_number(filename):
    return int(re.findall(r'\d+', filename)[-1])


for path, subdirs, files in sorted(os.walk(root_directory), key=lambda x: get_last_number(x[0])):
    dirname = path.split(os.path.sep)[-1]
    if dirname == 'masks':   # Find all 'masks' directories
        masks = os.listdir(path)  # List of all mask names in this subdirectory
        for i, mask_name in enumerate(sorted(masks)):
            if mask_name.endswith(".png"):   # Only read png images (masks in this dataset)
                mask = cv2.imread(os.path.join(path, mask_name), 1)  # Read each image as RGB
                mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
                size_x = (mask.shape[1] // patch_size) * patch_size  # Nearest size divisible by our patch size
                size_y = (mask.shape[0] // patch_size) * patch_size  # Nearest size divisible by our patch size

                new_x = size_x - (size_x % patch_size)
                new_y = size_y - (size_y % patch_size)

                mask = mask[:new_x, :new_y, :]

                # Extract patches from each image

                print("Now patchifying mask:", os.path.join(path, mask_name))
                mask_patches = patchify(mask, (patch_size, patch_size, 3), step=patch_size) 

                for i in range(mask_patches.shape[0]):
                    for j in range(mask_patches.shape[1]):
                        single_patch_mask = mask_patches[i, j, 0, :,:,:]
                        mask_dataset.append(single_patch_mask)
# Out:
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 1/masks/BOS12_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 1/masks/BOS12_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 1/masks/BOS12_8.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 1/masks/BOS12_9.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/masks/OLOM882_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/masks/OLOM882_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/masks/OLOM882_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/masks/OLOM882_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/masks/OLOM882_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 3/masks/OLOM882_5.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/masks/PROS36_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/masks/PROS36_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/masks/PROS36_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/masks/PROS36_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/masks/PROS36_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/masks/PROS36_5.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/masks/PROS36_6.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/masks/PROS36_7.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 4/masks/PROS36_8.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 5/masks/PROS83_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 5/masks/PROS83_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 5/masks/PROS83_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 5/masks/PROS83_5.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/masks/PROS362_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/masks/PROS362_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/masks/PROS362_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/masks/PROS362_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/masks/PROS362_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 6/masks/PROS362_5.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 7/masks/VYSK14_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 7/masks/VYSK14_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 7/masks/VYSK14_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 7/masks/VYSK14_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_10.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_11.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_12.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_13.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_5.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_6.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_7.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_8.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 8/masks/VYSK111_9.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 9/masks/VYSK112_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 9/masks/VYSK112_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 9/masks/VYSK112_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 9/masks/VYSK112_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 9/masks/VYSK112_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 10/masks/VYSK121_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 10/masks/VYSK121_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 10/masks/VYSK121_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 10/masks/VYSK121_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 11/masks/VYSK122_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 11/masks/VYSK122_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 11/masks/VYSK122_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 11/masks/VYSK122_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 12/masks/VYSK151_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 12/masks/VYSK151_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 12/masks/VYSK151_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 12/masks/VYSK151_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 12/masks/VYSK151_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 13/masks/VYSK152_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 13/masks/VYSK152_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 14/masks/BLAN981_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 14/masks/BLAN981_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 14/masks/BLAN981_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 14/masks/BLAN981_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 15/masks/BLAN982_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 15/masks/BLAN982_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 15/masks/BLAN982_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 15/masks/BLAN982_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_11.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_13.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_15.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_16.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_17.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_19.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_7.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_8.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 16/masks/KROM371_9.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_12.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_13.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_16.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_18.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_20.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_23.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_24.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_8.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 17/masks/MKRU491_9.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/masks/VYSK101_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/masks/VYSK101_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/masks/VYSK101_11.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/masks/VYSK101_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/masks/VYSK101_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/masks/VYSK101_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 18/masks/VYSK101_5.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/masks/VYSK131_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/masks/VYSK131_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/masks/VYSK131_10.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/masks/VYSK131_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/masks/VYSK131_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/masks/VYSK131_5.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/masks/VYSK131_6.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/masks/VYSK131_7.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 19/masks/VYSK131_8.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_14.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_15.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_16.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_17.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_18.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_5.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_6.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_7.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_8.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 20/masks/KROM341_9.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_10.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_11.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_12.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_13.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_14.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_15.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_5.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_6.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_7.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_8.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 21/masks/VYSK301_9.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/masks/VYSK302_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/masks/VYSK302_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/masks/VYSK302_10.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/masks/VYSK302_11.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/masks/VYSK302_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/masks/VYSK302_5.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 22/masks/VYSK302_8.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/masks/VYSK303_0.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/masks/VYSK303_1.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/masks/VYSK303_2.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/masks/VYSK303_3.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/masks/VYSK303_4.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/masks/VYSK303_5.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/masks/VYSK303_6.png
# Now patchifying mask: /home/nb1/pazdera/datasets/CZ_CUSTOM_DATASET/Semantic segmentation dataset V30 LITE/Tile 23/masks/VYSK303_8.png

# %%
image_dataset = np.array(image_dataset)/255.
mask_dataset =  np.array(mask_dataset)

print(image_dataset.shape)
print(mask_dataset.shape)

# print(np.unique(image_dataset))
# print(np.unique(mask_dataset))
# Out:
# (632, 512, 512, 3)
# (632, 512, 512, 3)

# %%
ran_i = random.randint(0,image_dataset.shape[0]-1)
print(image_dataset[ran_i])
print(mask_dataset[ran_i])
# Out:
# [[[0.34509804 0.37254902 0.34509804]
#   [0.45098039 0.47843137 0.45098039]
#   [0.47843137 0.50196078 0.48627451]
#   ...
#   [0.21568627 0.31764706 0.31372549]
#   [0.21176471 0.31372549 0.30980392]
#   [0.20784314 0.30980392 0.30588235]]
#
#  [[0.48627451 0.50588235 0.48235294]
#   [0.55686275 0.57647059 0.55294118]
#   [0.54117647 0.56470588 0.54901961]
#   ...
#   [0.21568627 0.31764706 0.31372549]
#   [0.21176471 0.31372549 0.30980392]
#   [0.20784314 0.30980392 0.30588235]]
#
#  [[0.50980392 0.52941176 0.50588235]
#   [0.54509804 0.56470588 0.54117647]
#   [0.51372549 0.5372549  0.52156863]
#   ...
#   [0.21568627 0.31764706 0.31372549]
#   [0.21176471 0.31372549 0.30980392]
#   [0.21176471 0.31372549 0.30980392]]
#
#  ...
#
#  [[0.49019608 0.58823529 0.4745098 ]
#   [0.48235294 0.58039216 0.46666667]
#   [0.4627451  0.56078431 0.44705882]
#   ...
#   [0.21176471 0.3254902  0.31764706]
#   [0.21176471 0.31372549 0.30980392]
#   [0.20392157 0.30588235 0.30196078]]
#
#  [[0.50196078 0.6        0.48627451]
#   [0.49019608 0.58823529 0.4745098 ]
#   [0.4627451  0.55294118 0.44313725]
#   ...
#   [0.20784314 0.32156863 0.30588235]
#   [0.21568627 0.31764706 0.30588235]
#   [0.21568627 0.31764706 0.30588235]]
#
#  [[0.47058824 0.56862745 0.45490196]
#   [0.45882353 0.55686275 0.44313725]
#   [0.42745098 0.51764706 0.40784314]
#   ...
#   [0.20392157 0.31764706 0.30196078]
#   [0.22352941 0.3254902  0.31372549]
#   [0.22745098 0.32941176 0.31764706]]]
# [[[ 50  50  50]
#   [ 50  50  50]
#   [ 50  50  50]
#   ...
#   [ 50 255 167]
#   [ 50 255 167]
#   [ 50 255 167]]
#
#  [[ 50  50  50]
#   [ 50  50  50]
#   [ 50  50  50]
#   ...
#   [ 50 255 167]
#   [ 50 255 167]
#   [ 50 255 167]]
#
#  [[ 50  50  50]
#   [ 50  50  50]
#   [ 50  50  50]
#   ...
#   [ 50 255 167]
#   [ 50 255 167]
#   [ 50 255 167]]
#
#  ...
#
#  [[ 50 255 167]
#   [ 50 255 167]
#   [ 50 255 167]
#   ...
#   [ 50 255 167]
#   [ 50 255 167]
#   [ 50 255 167]]
#
#  [[ 50 255 167]
#   [ 50 255 167]
#   [ 50 255 167]
#   ...
#   [ 50 255 167]
#   [ 50 255 167]
#   [ 50 255 167]]
#
#  [[ 50 255 167]
#   [ 50 255 167]
#   [ 50 255 167]
#   ...
#   [ 50 255 167]
#   [ 50 255 167]
#   [ 50 255 167]]]

# %%
ran_i = random.randint(0,image_dataset.shape[0]-1)
one_image = image_dataset[ran_i,:,:,:]
one_mask = mask_dataset[ran_i,:,:,:]
plt.imshow(one_image)
plt.show()
plt.imshow(one_mask)
plt.show()

# %%
# visually chcecking RGB format of loaded images and masks

r_num = random.randint(0, len(image_dataset)-1)

plt.figure(figsize=(9,6))
plt.subplot(1, 2, 1)
plt.axis('off')
plt.imshow(image_dataset[r_num])
plt.subplot(1, 2, 2)
plt.axis('off')
plt.imshow(mask_dataset[r_num])

# %%
Unlabelled = [50,50,50]
Vegetation = [50,255,167]
Unpaved_road = [255,140,0]
Paved_area = [109,50,255]
Building = [255,225,50]
Water = [50,167,255]
Land = [166, 117, 86]

# %%
# Clasess have to be in array format
# Following function converts RGB to integer values representing classes


def rgb_to_2D_label(label):

    label_seg = np.zeros(label.shape,dtype=np.uint8)
    label_seg [np.all(label == Unlabelled,axis=-1)] = 0
    label_seg [np.all(label==Vegetation,axis=-1)] = 1
    label_seg [np.all(label==Unpaved_road,axis=-1)] = 2
    label_seg [np.all(label==Paved_area,axis=-1)] = 3
    label_seg [np.all(label==Building,axis=-1)] = 4
    label_seg [np.all(label==Water,axis=-1)] = 5
    label_seg [np.all(label==Land,axis=-1)] = 6
    
    label_seg = label_seg[:,:,0]  #Just take the first channel, no need for all 3 channels
    
    return label_seg

# %%
mask_sample = single_patch_mask
print(mask_sample.shape, np.unique(mask_sample))

single_label = rgb_to_2D_label(mask_sample)
print(single_label.shape, np.unique(single_label))
# Out:
# (512, 512, 3) [ 50 167 255]
# (512, 512) [1]

# %%
# Converting masks to labels according to defined classes
# Expanding dims so the format is correct for model input

labels = []
for i in range(mask_dataset.shape[0]):
    label = rgb_to_2D_label(mask_dataset[i])
    labels.append(label)    

labels = np.array(labels)   
labels = np.expand_dims(labels, axis=3)
 

# print("Unique labels in label dataset are: ", np.unique(labels))
print("Shape of labels: ", labels.shape)
#print(np.unique(labels))
#print(len(np.unique(labels)))
# Out:
# Shape of labels:  (632, 512, 512, 1)

# %%
# Sanity check
# The mask colors are not the same as we defined, because the input here is only label with integers <0,5>
# The function imshow uses different color scheme

image_number = random.randint(0, len(image_dataset-1))
plt.figure(figsize=(9,6))
plt.subplot(1, 2, 1)
plt.imshow(image_dataset[image_number])
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(labels[image_number][:,:,0])
plt.axis('off')
plt.show()

# %%
# Setting number of classes for further processing
# Checking if the expected number of classes corresponds to the number of unique labels in our dataset

n_classes = 7

"""
if n_classes == len(np.unique(labels)):
    print("Number of classes is correct")
else:
    print("Houston, we've had a problem")
"""
# Out:
# '\nif n_classes == len(np.unique(labels)):\n    print("Number of classes is correct")\nelse:\n    print("Houston, we\'ve had a problem")\n'

# %%
# Converting to onehot encode
# This format corresponds to output of the neural network

labels_cat = to_categorical(labels, num_classes=n_classes)

print(labels_cat.shape)
# print(np.unique(labels_cat))
# Out:
# (632, 512, 512, 7)

# %%
# Dividing all data into train and test parts

X_train, X_test, Y_train, Y_test = train_test_split(image_dataset, labels_cat, test_size=0.20)

# print(X_train.shape, np.unique(X_train))
# print(Y_train.shape, np.unique(Y_train))

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (505, 512, 512, 3)
# (505, 512, 512, 7)
# (127, 512, 512, 3)
# (127, 512, 512, 7)

# %%
# Initialize the parameters of our model

from simple_multi_unet_model import jacard_coef

#weights = [0.05, 0.40, 0.30, 0.10, 0.10, 0.05]
weights = [0.143, 0.143, 0.143, 0.143, 0.143, 0.143, 0.143]
dice_loss = sm.losses.DiceLoss(class_weights=weights)
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1*focal_loss)

IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

metrics = ['accuracy', jacard_coef]

# %%
# Getting model, summary

def get_model():
    return multi_unet_model(n_classes=n_classes, IMG_HEIGHT=IMG_HEIGHT, IMG_WIDTH=IMG_WIDTH, IMG_CHANNELS=IMG_CHANNELS)

model = get_model()
# model.compile(optimizer='adam', loss = "categorical_crossentropy", metrics=metrics)
model.compile(optimizer='adam', loss = total_loss, metrics=metrics)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 16) 448         input_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512, 512, 16) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 16) 2320        dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 256, 256, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 32) 9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 32) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 128, 64) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 64) 36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 128)  147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 256)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 256)  590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 64, 64, 128)  131200      conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 256)  0           conv2d_transpose[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 64, 64, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 128)  147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 128, 128, 64) 32832       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_1[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128, 128, 64) 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 64) 36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 256, 32) 8224        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 256, 256, 32) 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 32) 9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 512, 512, 16) 2064        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512, 512, 32) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 512, 512, 16) 4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 512, 512, 16) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 512, 512, 16) 2320        dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 7)  119         conv2d_17[0][0]
# ==================================================================================================
# Total params: 1,941,207
# Trainable params: 1,941,207
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2024-04-27 11:34:45.944739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:45.944853: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:45.944907: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:45.945217: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:45.945286: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:45.945336: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:45.945413: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:45.945465: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-27 11:34:45.945508: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9666 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
history1 = model.fit(X_train, Y_train, 
                    batch_size = 1, 
                    verbose=1, 
                    epochs=50,
                    validation_data=(X_test, Y_test),
                    shuffle=False)
# Out:
# 2024-04-27 11:34:46.379155: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1588592640 exceeds 10% of free system memory.
# 2024-04-27 11:34:46.926467: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 3706716160 exceeds 10% of free system memory.
# 2024-04-27 11:34:48.168569: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1588592640 exceeds 10% of free system memory.
# 2024-04-27 11:34:48.588683: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 3706716160 exceeds 10% of free system memory.
# 2024-04-27 11:34:49.574651: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2024-04-27 11:34:50.654164: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8907
# 2024-04-27 11:34:50.738848: W tensorflow/stream_executor/gpu/asm_compiler.cc:231] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-04-27 11:34:50.738865: W tensorflow/stream_executor/gpu/asm_compiler.cc:234] Used ptxas at ptxas
# 2024-04-27 11:34:50.739034: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Unimplemented: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 505/505 [==============================] - 13s 20ms/step - loss: 1.0045 - accuracy: 0.7129 - jacard_coef: 0.4174 - val_loss: 0.9892 - val_accuracy: 0.7956 - val_jacard_coef: 0.6415
# Epoch 2/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9902 - accuracy: 0.7962 - jacard_coef: 0.5749 - val_loss: 0.9844 - val_accuracy: 0.8602 - val_jacard_coef: 0.6713
# Epoch 3/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9855 - accuracy: 0.8251 - jacard_coef: 0.6132 - val_loss: 1.0080 - val_accuracy: 0.7238 - val_jacard_coef: 0.6156
# Epoch 4/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9836 - accuracy: 0.8391 - jacard_coef: 0.6268 - val_loss: 0.9800 - val_accuracy: 0.8726 - val_jacard_coef: 0.6975
# Epoch 5/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9823 - accuracy: 0.8398 - jacard_coef: 0.6446 - val_loss: 0.9789 - val_accuracy: 0.8769 - val_jacard_coef: 0.7107
# Epoch 6/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9807 - accuracy: 0.8428 - jacard_coef: 0.6611 - val_loss: 0.9780 - val_accuracy: 0.8791 - val_jacard_coef: 0.7111
# Epoch 7/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9797 - accuracy: 0.8443 - jacard_coef: 0.6694 - val_loss: 0.9773 - val_accuracy: 0.8779 - val_jacard_coef: 0.7216
# Epoch 8/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9789 - accuracy: 0.8445 - jacard_coef: 0.6778 - val_loss: 0.9766 - val_accuracy: 0.8813 - val_jacard_coef: 0.7313
# Epoch 9/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9775 - accuracy: 0.8464 - jacard_coef: 0.6916 - val_loss: 0.9756 - val_accuracy: 0.8820 - val_jacard_coef: 0.7356
# Epoch 10/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9766 - accuracy: 0.8498 - jacard_coef: 0.6998 - val_loss: 0.9755 - val_accuracy: 0.8844 - val_jacard_coef: 0.7508
# Epoch 11/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9759 - accuracy: 0.8530 - jacard_coef: 0.7054 - val_loss: 0.9754 - val_accuracy: 0.8845 - val_jacard_coef: 0.7536
# Epoch 12/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9758 - accuracy: 0.8535 - jacard_coef: 0.7048 - val_loss: 0.9751 - val_accuracy: 0.8848 - val_jacard_coef: 0.7529
# Epoch 13/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9753 - accuracy: 0.8557 - jacard_coef: 0.7094 - val_loss: 0.9758 - val_accuracy: 0.8838 - val_jacard_coef: 0.7603
# Epoch 14/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9748 - accuracy: 0.8590 - jacard_coef: 0.7134 - val_loss: 0.9752 - val_accuracy: 0.8867 - val_jacard_coef: 0.7618
# Epoch 15/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9746 - accuracy: 0.8600 - jacard_coef: 0.7150 - val_loss: 0.9752 - val_accuracy: 0.8871 - val_jacard_coef: 0.7632
# Epoch 16/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9752 - accuracy: 0.8532 - jacard_coef: 0.7080 - val_loss: 0.9760 - val_accuracy: 0.8601 - val_jacard_coef: 0.7225
# Epoch 17/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9740 - accuracy: 0.8628 - jacard_coef: 0.7183 - val_loss: 0.9750 - val_accuracy: 0.8887 - val_jacard_coef: 0.7705
# Epoch 18/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9739 - accuracy: 0.8631 - jacard_coef: 0.7218 - val_loss: 0.9754 - val_accuracy: 0.8877 - val_jacard_coef: 0.7703
# Epoch 19/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9739 - accuracy: 0.8628 - jacard_coef: 0.7203 - val_loss: 0.9753 - val_accuracy: 0.8889 - val_jacard_coef: 0.7734
# Epoch 20/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9736 - accuracy: 0.8641 - jacard_coef: 0.7232 - val_loss: 0.9757 - val_accuracy: 0.8884 - val_jacard_coef: 0.7707
# Epoch 21/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9733 - accuracy: 0.8666 - jacard_coef: 0.7257 - val_loss: 0.9757 - val_accuracy: 0.8886 - val_jacard_coef: 0.7751
# Epoch 22/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9730 - accuracy: 0.8681 - jacard_coef: 0.7280 - val_loss: 0.9758 - val_accuracy: 0.8893 - val_jacard_coef: 0.7771
# Epoch 23/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9733 - accuracy: 0.8659 - jacard_coef: 0.7250 - val_loss: 0.9772 - val_accuracy: 0.8843 - val_jacard_coef: 0.7675
# Epoch 24/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9728 - accuracy: 0.8692 - jacard_coef: 0.7292 - val_loss: 0.9765 - val_accuracy: 0.8883 - val_jacard_coef: 0.7741
# Epoch 25/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9728 - accuracy: 0.8685 - jacard_coef: 0.7283 - val_loss: 0.9757 - val_accuracy: 0.8915 - val_jacard_coef: 0.7818
# Epoch 26/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9726 - accuracy: 0.8700 - jacard_coef: 0.7314 - val_loss: 0.9774 - val_accuracy: 0.8850 - val_jacard_coef: 0.7733
# Epoch 27/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9722 - accuracy: 0.8715 - jacard_coef: 0.7355 - val_loss: 0.9753 - val_accuracy: 0.8926 - val_jacard_coef: 0.7830
# Epoch 28/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9723 - accuracy: 0.8717 - jacard_coef: 0.7339 - val_loss: 0.9763 - val_accuracy: 0.8907 - val_jacard_coef: 0.7824
# Epoch 29/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9730 - accuracy: 0.8686 - jacard_coef: 0.7249 - val_loss: 0.9770 - val_accuracy: 0.8890 - val_jacard_coef: 0.7779
# Epoch 30/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9718 - accuracy: 0.8738 - jacard_coef: 0.7388 - val_loss: 0.9759 - val_accuracy: 0.8918 - val_jacard_coef: 0.7897
# Epoch 31/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9715 - accuracy: 0.8755 - jacard_coef: 0.7414 - val_loss: 0.9768 - val_accuracy: 0.8896 - val_jacard_coef: 0.7869
# Epoch 32/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9732 - accuracy: 0.8638 - jacard_coef: 0.7283 - val_loss: 0.9760 - val_accuracy: 0.8713 - val_jacard_coef: 0.7282
# Epoch 33/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9718 - accuracy: 0.8756 - jacard_coef: 0.7359 - val_loss: 0.9765 - val_accuracy: 0.8922 - val_jacard_coef: 0.7659
# Epoch 34/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9715 - accuracy: 0.8747 - jacard_coef: 0.7415 - val_loss: 0.9756 - val_accuracy: 0.8919 - val_jacard_coef: 0.7940
# Epoch 35/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9709 - accuracy: 0.8785 - jacard_coef: 0.7479 - val_loss: 0.9761 - val_accuracy: 0.8923 - val_jacard_coef: 0.7861
# Epoch 36/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9707 - accuracy: 0.8792 - jacard_coef: 0.7521 - val_loss: 0.9767 - val_accuracy: 0.8861 - val_jacard_coef: 0.7751
# Epoch 37/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9705 - accuracy: 0.8797 - jacard_coef: 0.7520 - val_loss: 0.9778 - val_accuracy: 0.8888 - val_jacard_coef: 0.7834
# Epoch 38/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9710 - accuracy: 0.8756 - jacard_coef: 0.7474 - val_loss: 0.9738 - val_accuracy: 0.8965 - val_jacard_coef: 0.7888
# Epoch 39/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9710 - accuracy: 0.8792 - jacard_coef: 0.7434 - val_loss: 0.9782 - val_accuracy: 0.8851 - val_jacard_coef: 0.7803
# Epoch 40/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9707 - accuracy: 0.8795 - jacard_coef: 0.7520 - val_loss: 0.9783 - val_accuracy: 0.8806 - val_jacard_coef: 0.7764
# Epoch 41/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9701 - accuracy: 0.8826 - jacard_coef: 0.7580 - val_loss: 0.9780 - val_accuracy: 0.8826 - val_jacard_coef: 0.7793
# Epoch 42/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9699 - accuracy: 0.8836 - jacard_coef: 0.7612 - val_loss: 0.9764 - val_accuracy: 0.8875 - val_jacard_coef: 0.7840
# Epoch 43/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9703 - accuracy: 0.8820 - jacard_coef: 0.7582 - val_loss: 0.9789 - val_accuracy: 0.8783 - val_jacard_coef: 0.7623
# Epoch 44/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9698 - accuracy: 0.8840 - jacard_coef: 0.7614 - val_loss: 0.9776 - val_accuracy: 0.8356 - val_jacard_coef: 0.7294
# Epoch 45/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9705 - accuracy: 0.8789 - jacard_coef: 0.7525 - val_loss: 0.9773 - val_accuracy: 0.8870 - val_jacard_coef: 0.7853
# Epoch 46/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9696 - accuracy: 0.8847 - jacard_coef: 0.7635 - val_loss: 0.9786 - val_accuracy: 0.8765 - val_jacard_coef: 0.7744
# Epoch 47/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9698 - accuracy: 0.8825 - jacard_coef: 0.7571 - val_loss: 0.9735 - val_accuracy: 0.8966 - val_jacard_coef: 0.7959
# Epoch 48/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9694 - accuracy: 0.8866 - jacard_coef: 0.7611 - val_loss: 0.9749 - val_accuracy: 0.8966 - val_jacard_coef: 0.7781
# Epoch 49/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9692 - accuracy: 0.8880 - jacard_coef: 0.7679 - val_loss: 0.9745 - val_accuracy: 0.8972 - val_jacard_coef: 0.8025
# Epoch 50/50
# 505/505 [==============================] - 9s 18ms/step - loss: 0.9690 - accuracy: 0.8880 - jacard_coef: 0.7696 - val_loss: 0.9759 - val_accuracy: 0.8938 - val_jacard_coef: 0.7633

# %%
model_path = "/home/nb1/pazdera/model_512_50_DSV30LITE_fd.h5"
model.save(model_path)
